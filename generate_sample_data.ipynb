# %%
# Generate Sample Data
import pandas as pd
import numpy as np
import os

# %%
# Simple sample data
countries = ['Afghanistan', 'India', 'China', 'USA', 'France']
years = list(range(2000, 2024))

# %%
# Create sample yields
data = []
for country in countries:
    for year in years:
        yield_value = 2000 + (year - 2000) * 50 + np.random.normal(0, 200)
        data.append({'Country': country, 'Year': year, 'Yield': yield_value})

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#          Country  Year        Yield
# 0    Afghanistan  2000  2221.491834
# 1    Afghanistan  2001  1821.654463
# 2    Afghanistan  2002  1971.499810
# 3    Afghanistan  2003  2189.480697
# 4    Afghanistan  2004  2184.918700
# ..           ...   ...          ...
# 115       France  2019  3052.372895
# 116       France  2020  2872.930576
# 117       France  2021  2989.921257
# 118       France  2022  3238.551608
# 119       France  2023  2791.893320
#
# [120 rows x 3 columns]

# %%
# Test Visualisation

import matplotlib.pyplot as plt

# Create a simple plot
fig, ax = plt.subplots(figsize=(10, 6))

for country in ['Afghanistan', 'India', 'China']:
    country_data = df[df['Country'] == country]
    ax.plot(country_data['Year'], country_data['Yield'], 
            marker='o', label=country, linewidth=2)

ax.set_title("Wheat Yield Over Time", fontsize=16)
ax.set_xlabel("Year")
ax.set_ylabel("Yield (kg/ha)")
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
