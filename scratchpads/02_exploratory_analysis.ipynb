# %% [markdown]
# #### Investigating whether yield trends in major producing countries can be used to predict yields in other countries

# %% [markdown]
# #### Exploratory Data Analysis

# %% [markdown]
# Quick explore of additional data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
importexport = pd.read_csv('../data/import_export_data.csv')
clean_yield = pd.read_csv('../data/extracleaned_wheat_data.csv')

# %%
importexport
# Out:
#                              Domain         Area          Element   Item  \
# 0      Crops and livestock products  Afghanistan  Import quantity  Wheat
# 1      Crops and livestock products  Afghanistan  Import quantity  Wheat
# 2      Crops and livestock products  Afghanistan  Import quantity  Wheat
# 3      Crops and livestock products  Afghanistan  Import quantity  Wheat
# 4      Crops and livestock products  Afghanistan  Import quantity  Wheat
# ...                             ...          ...              ...    ...
# 18291  Crops and livestock products     Zimbabwe  Import quantity  Wheat
# 18292  Crops and livestock products     Zimbabwe  Import quantity  Wheat
# 18293  Crops and livestock products     Zimbabwe  Export quantity  Wheat
# 18294  Crops and livestock products     Zimbabwe  Import quantity  Wheat
# 18295  Crops and livestock products     Zimbabwe  Export quantity  Wheat
#
#        Year Unit      Value
# 0      1961    t   32400.00
# 1      1962    t    6800.00
# ...

# %%
importexport = importexport.drop(columns=['Domain','Item','Unit'])

# %%
importexport
# Out:
#               Area          Element  Year      Value
# 0      Afghanistan  Import quantity  1961   32400.00
# 1      Afghanistan  Import quantity  1962    6800.00
# 2      Afghanistan  Import quantity  1963   79900.00
# 3      Afghanistan  Import quantity  1964  106092.00
# 4      Afghanistan  Import quantity  1965  107000.00
# ...            ...              ...   ...        ...
# 18291     Zimbabwe  Import quantity  2021  180725.49
# 18292     Zimbabwe  Import quantity  2022  172774.30
# 18293     Zimbabwe  Export quantity  2022      10.50
# 18294     Zimbabwe  Import quantity  2023  258404.63
# 18295     Zimbabwe  Export quantity  2023     124.30
#
# [18296 rows x 4 columns]

# %%
clean_yield
# Out:
#      Area Code                                     Area   Y1961   Y1962  \
# 0            2                              Afghanistan  1022.0   973.5
# 1            3                                  Albania   773.1  1052.2
# 2            4                                  Algeria   406.0   804.5
# 3            7                                   Angola  1111.1  1111.1
# 4            9                                Argentina  1295.0  1522.2
# ..         ...                                      ...     ...     ...
# 118       5801                Least Developed Countries   935.1   907.4
# 119       5802         Land Locked Developing Countries   948.9   957.4
# 120       5803           Small Island Developing States  2500.0  2500.0
# 121       5815        Low Income Food Deficit Countries   835.3   917.9
# 122       5817  Net Food Importing Developing Countries   853.9   952.4
#
#       Y1963   Y1964   Y1965   Y1966   Y1967   Y1968  ...   Y2014   Y2015  \
# ...

# %%
importexport_wide = importexport.pivot_table(
    index=["Area", "Element"],
    columns = "Year",
    values = "Value"
)

# %%
importexport_wide
# Out:
# Year                              1961      1962       1963      1964  \
# Area         Element
# Afghanistan  Export quantity       NaN       NaN        NaN       NaN
#              Import quantity   32400.0    6800.0    79900.0  106092.0
# Albania      Export quantity       0.0       0.0        0.0       0.0
#              Import quantity  182400.0   89100.0   109800.0  110700.0
# Algeria      Export quantity     270.0     300.0      242.0   15000.0
# ...                                ...       ...        ...       ...
# Yugoslav SFR Import quantity  745504.0  734612.0  1438831.0  610672.0
# Zambia       Export quantity       NaN       NaN        NaN       NaN
#              Import quantity   21000.0   16000.0    21000.0   18900.0
# Zimbabwe     Export quantity       0.0     800.0     1500.0    5700.0
#              Import quantity   84880.0   63680.0    82380.0   78800.0
#
# Year                               1965       1966      1967     1968  \
# Area         Element
# ...

# %%
clean_yield = clean_yield[clean_yield["Area Code"] < 5000]
clean_yield.drop(columns=["Area Code"], inplace=True)
countries = clean_yield["Area"].unique().tolist()
#importexport_wide_filtered = importexport_wide[importexport_wide[index].isin(countries)]
countries
# Out:
# /var/folders/6z/5ds6pqr14hq4rzt701_p13lr0000gn/T/ipykernel_67107/478073910.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_yield.drop(columns=["Area Code"], inplace=True)
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Bangladesh',
#  'Bhutan',
#  'Bolivia (Plurinational State of)',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burundi',
#  'Canada',
#  'Chad',
#  'Chile',
#  'China',
#  'China, mainland',
#  'China, Taiwan Province of',
#  'Colombia',
#  'Cyprus',
#  'Democratic Peoples Republic of Korea',
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Ecuador',
#  'Egypt',
#  'Eswatini',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Guatemala',
#  'Honduras',
#  'Hungary',
#  'India',
# ...

# %%
importexport_wide_filtered = importexport_wide[importexport_wide["Area"].isin(countries)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/DataScienceMachineLearning/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Area'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 importexport_wide_filtered = importexport_wide[importexport_wide["Area"].isin(countries)]
#
# ...
